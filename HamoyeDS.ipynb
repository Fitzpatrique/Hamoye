# %% [markdown]
# <a href="https://colab.research.google.com/github/Fitzpatrique/Hamoye/blob/master/HamoyeDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv"

# %%
df = pd.read_csv(url)

# %%
df.to_csv('Electric Utility.csv')

# %%
df.head()
# Out:
#                 record_id  ...  fuel_cost_per_mmbtu
# 0   f1_fuel_1994_12_1_0_7  ...                1.121
# 1  f1_fuel_1994_12_1_0_10  ...                1.120
# 2   f1_fuel_1994_12_2_0_1  ...                1.650
# 3   f1_fuel_1994_12_2_0_7  ...                1.970
# 4  f1_fuel_1994_12_2_0_10  ...                2.570
#
# [5 rows x 11 columns]

# %%
df.corr()
# Out:
#                               utility_id_ferc1  ...  Total_mmbtu_burned
# utility_id_ferc1                      1.000000  ...           -0.038765
# report_year                           0.093267  ...           -0.035004
# fuel_qty_burned                      -0.058025  ...            0.448885
# fuel_mmbtu_per_unit                  -0.069000  ...            0.245332
# fuel_cost_per_unit_burned            -0.037868  ...           -0.007012
# fuel_cost_per_unit_delivered         -0.016434  ...           -0.001772
# fuel_cost_per_mmbtu                   0.005884  ...           -0.001102
# Total_mmbtu_burned                   -0.038765  ...            1.000000
#
# [8 rows x 8 columns]

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.describe()
# Out:
#        utility_id_ferc1  ...  fuel_cost_per_mmbtu
# count      29523.000000  ...         29523.000000
# mean         118.601836  ...            19.304354
# std           74.178353  ...          2091.540939
# min            1.000000  ...           -41.501000
# 25%           55.000000  ...             1.940000
# 50%          122.000000  ...             4.127000
# 75%          176.000000  ...             7.745000
# max          514.000000  ...        359278.000000
#
# [8 rows x 7 columns]

# %%
df.duplicated().any()

# %%
df.dropna(axis=0, inplace=True)
df.tail()
# Out:
#                      record_id  ...  fuel_cost_per_mmbtu
# 29518  f1_fuel_2018_12_12_0_13  ...                 9.03
# 29519   f1_fuel_2018_12_12_1_1  ...                 6.95
# 29520  f1_fuel_2018_12_12_1_10  ...                 8.99
# 29521  f1_fuel_2018_12_12_1_13  ...                 1.11
# 29522  f1_fuel_2018_12_12_1_14  ...                11.68
#
# [5 rows x 11 columns]

# %%
len(df.columns)

# %%
df['fuel_unit'].unique()

# %%
df['Total_mmbtu_burned'] = df['fuel_qty_burned'] * df['fuel_mmbtu_per_unit']

# %%
df.head()
# Out:
#                 record_id  ...  Total_mmbtu_burned
# 0   f1_fuel_1994_12_1_0_7  ...        8.921254e+07
# 1  f1_fuel_1994_12_1_0_10  ...        1.739994e+08
# 2   f1_fuel_1994_12_2_0_1  ...        7.187562e+07
# 3   f1_fuel_1994_12_2_0_7  ...        8.956064e+07
# 4  f1_fuel_1994_12_2_0_10  ...        4.053300e+04
#
# [5 rows x 12 columns]

# %%
sns.boxplot(x='fuel_type_code_pudl', y='Total_mmbtu_burned', data = df)

# %%
 sns.boxplot(x='report_year', y='Total_mmbtu_burned', data = df)

# %%
(180/29523)*100
# Out:
# 0.609694136774718

# %%
df.corr()
# Out:
#                               utility_id_ferc1  ...  Total_mmbtu_burned
# utility_id_ferc1                      1.000000  ...           -0.038765
# report_year                           0.093267  ...           -0.035004
# fuel_qty_burned                      -0.058025  ...            0.448885
# fuel_mmbtu_per_unit                  -0.069000  ...            0.245332
# fuel_cost_per_unit_burned            -0.037868  ...           -0.007012
# fuel_cost_per_unit_delivered         -0.016434  ...           -0.001772
# fuel_cost_per_mmbtu                   0.005884  ...           -0.001102
# Total_mmbtu_burned                   -0.038765  ...            1.000000
#
# [8 rows x 8 columns]

# %%
 sns.boxplot(x='fuel_type_code_pudl', y='utility_id_ferc1', data = df)

# %%
 df.groupby('fuel_type_code_pudl').describe()
# Out:
#                     utility_id_ferc1              ... Total_mmbtu_burned
#                                count        mean  ...                75%           max
# fuel_type_code_pudl                               ...
# coal                          8496.0  115.626530  ...       4.353945e+07  1.284783e+10
# gas                          11433.0  123.938774  ...       3.289797e+06  1.685969e+08
# nuclear                        803.0  107.039851  ...       4.211641e+07  8.213062e+09
# oil                           8043.0  113.204650  ...       1.043683e+05  2.631734e+08
# other                          131.0  105.938931  ...       8.399918e+02  1.049869e+06
# waste                          437.0  154.830664  ...       1.070070e+03  4.811201e+06
#
# [6 rows x 64 columns]

# %%
df4 =  df.groupby('fuel_type_code_pudl').describe()['Total_mmbtu_burned']

# %%
df4
# Out:
#                        count          mean  ...           75%           max
# fuel_type_code_pudl                         ...
# coal                  8496.0  3.877062e+07  ...  4.353945e+07  1.284783e+10
# gas                  11433.0  4.969345e+06  ...  3.289797e+06  1.685969e+08
# nuclear                803.0  4.225757e+07  ...  4.211641e+07  8.213062e+09
# oil                   8043.0  3.863671e+05  ...  1.043683e+05  2.631734e+08
# other                  131.0  4.524854e+04  ...  8.399918e+02  1.049869e+06
# waste                  437.0  1.542354e+05  ...  1.070070e+03  4.811201e+06
#
# [6 rows x 8 columns]

# %%
df4.reset_index(inplace=True)

# %%
a = [1,2,3]
b =[4,5,6]
c = a.extend(b)
print(c)
# Out:
# None

# %%
df4
# Out:
#   fuel_type_code_pudl    count  ...           75%           max
# 0                coal   8496.0  ...  4.353945e+07  1.284783e+10
# 1                 gas  11433.0  ...  3.289797e+06  1.685969e+08
# 2             nuclear    803.0  ...  4.211641e+07  8.213062e+09
# 3                 oil   8043.0  ...  1.043683e+05  2.631734e+08
# 4               other    131.0  ...  8.399918e+02  1.049869e+06
# 5               waste    437.0  ...  1.070070e+03  4.811201e+06
#
# [6 rows x 9 columns]

# %%
 plt.bar(df4['fuel_type_code_pudl'],df4['max'])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(df4['fuel_type_code_pudl'],df4['min'])
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(df4['fuel_type_code_pudl'],df4['count'])
# Out:
# <BarContainer object of 6 artists>

# %%
df.groupby('report_year'). describe()
# Out:
#             utility_id_ferc1              ... Total_mmbtu_burned
#                        count        mean  ...                75%           max
# report_year                               ...
# 1994                  1213.0  105.796373  ...       1.785689e+07  8.444636e+08
# 1995                  1184.0  110.161318  ...       1.933238e+07  1.284783e+10
# 1996                  1080.0  108.947222  ...       2.066356e+07  2.078144e+08
# 1997                  1091.0  108.371219  ...       1.970416e+07  2.632560e+09
# 1998                  1100.0  109.916364  ...       2.182798e+07  8.213062e+09
# 1999                  1042.0  108.192898  ...       2.321052e+07  1.107194e+09
# 2000                  1368.0  111.016813  ...       1.353440e+07  1.096863e+09
# 2001                  1345.0  113.388848  ...       1.089396e+07  1.707273e+09
# 2002                  1195.0  119.953138  ...       1.049254e+07  2.747165e+09
# ...

# %%
new_df2 = df.groupby('report_year'). describe()['Total_mmbtu_burned']

# %%
new_df2.reset_index(inplace= True)

# %%
new_df2
# Out:
#     report_year   count          mean  ...           50%           75%           max
# 0          1994  1213.0  1.524312e+07  ...  1.799716e+06  1.785689e+07  8.444636e+08
# 1          1995  1184.0  2.621895e+07  ...  2.914102e+06  1.933238e+07  1.284783e+10
# 2          1996  1080.0  1.623455e+07  ...  2.023148e+06  2.066356e+07  2.078144e+08
# 3          1997  1091.0  2.262099e+07  ...  2.259223e+06  1.970416e+07  2.632560e+09
# 4          1998  1100.0  2.708101e+07  ...  3.290056e+06  2.182798e+07  8.213062e+09
# 5          1999  1042.0  2.056274e+07  ...  3.913381e+06  2.321052e+07  1.107194e+09
# 6          2000  1368.0  1.551535e+07  ...  6.624346e+05  1.353440e+07  1.096863e+09
# 7          2001  1345.0  1.468644e+07  ...  4.285753e+05  1.089396e+07  1.707273e+09
# 8          2002  1195.0  1.565406e+07  ...  3.827567e+05  1.049254e+07  2.747165e+09
# 9          2003  1205.0  1.530628e+07  ...  2.527553e+05  9.146963e+06  1.996394e+09
# ...

# %%
((216.7-126)/216.7)*100
# Out:
# 41.855099215505305

# %%
df['fuel_unit'].nunique()

# %%
df['fuel_unit'].value_counts()
# Out:
# mcf       11354
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
new_df = df['fuel_unit'].value_counts()

# %%
new_df
# Out:
# mcf       11354
# ton        8958
# bbl        7998
# gramsU      464
# mmbtu       180
# kgU         110
# mwhth       100
# mwdth        95
# gal          84
# Name: fuel_unit, dtype: int64

# %%
new_df = pd.DataFrame(df['fuel_unit'].value_counts())

# %%
new_df
# Out:
#         fuel_unit
# mcf         11354
# ton          8958
# bbl          7998
# gramsU        464
# mmbtu         180
# kgU           110
# mwhth         100
# mwdth          95
# gal            84

# %%
new_df.reset_index(inplace=True)

# %%
new_df
# Out:
#     index  fuel_unit
# 0     mcf      11354
# 1     ton       8958
# 2     bbl       7998
# 3  gramsU        464
# 4   mmbtu        180
# 5     kgU        110
# 6   mwhth        100
# 7   mwdth         95
# 8     gal         84

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.bar(new_df2['report_year'],new_df2['mean'])
# Out:
# <BarContainer object of 25 artists>

# %%
 plt.bar(new_df2['report_year'],new_df2['count'])
# Out:
# <BarContainer object of 25 artists>

# %%
 plt.bar(new_df2['report_year'],new_df2['max'])
# Out:
# <BarContainer object of 25 artists>

# %%
 
x = new_df['index']
y = new_df['fuel_unit']

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9 artists>

# %%
sns.barplot(x, y)
plt.xlabel = 'Fuel Unit'
plt.ylabel = 'Count'

# %%
df.groupby('fuel_unit').describe()
# Out:
#           utility_id_ferc1              ... Total_mmbtu_burned
#                      count        mean  ...                75%           max
# fuel_unit                               ...
# bbl                 7998.0  113.042261  ...       1.003676e+05  2.631734e+08
# gal                   84.0  114.571429  ...       3.129095e+06  1.478837e+07
# gramsU               464.0  125.198276  ...       3.576992e+07  1.960713e+08
# kgU                  110.0   53.181818  ...       9.225129e+01  9.077104e+04
# mcf                11354.0  123.854236  ...       3.322159e+06  1.685969e+08
# mmbtu                180.0   96.544444  ...       2.689796e+08  2.632560e+09
# mwdth                 95.0   88.178947  ...       2.864222e+06  1.746886e+07
# mwhth                100.0  111.800000  ...       1.141288e+08  8.213062e+09
# ton                 8958.0  117.939049  ...       4.065852e+07  1.284783e+10
#
# [9 rows x 64 columns]

# %%
df3 = df.groupby('fuel_unit').describe()['Total_mmbtu_burned']

# %%
df3.reset_index(inplace=True)

# %%
df3
# Out:
#   fuel_unit    count          mean  ...           50%           75%           max
# 0       bbl   7998.0  3.614152e+05  ...  2.783975e+04  1.003676e+05  2.631734e+08
# 1       gal     84.0  1.993912e+06  ...  5.317405e+05  3.129095e+06  1.478837e+07
# 2    gramsU    464.0  2.288482e+07  ...  7.870418e+04  3.576992e+07  1.960713e+08
# 3       kgU    110.0  3.602328e+03  ...  3.371912e+01  9.225129e+01  9.077104e+04
# 4       mcf  11354.0  5.008420e+06  ...  4.106643e+05  3.322159e+06  1.685969e+08
# 5     mmbtu    180.0  1.559460e+08  ...  9.290539e+05  2.689796e+08  2.632560e+09
# 6     mwdth     95.0  2.598938e+06  ...  9.460426e+04  2.864222e+06  1.746886e+07
# 7     mwhth    100.0  1.799085e+08  ...  9.414289e+07  1.141288e+08  8.213062e+09
# 8       ton   8958.0  3.421218e+07  ...  1.876763e+07  4.065852e+07  1.284783e+10
#
# [9 rows x 9 columns]

# %%
plt.bar(df3['fuel_unit'],df3['max'])
# Out:
# <BarContainer object of 9 artists>

# %%
Data = [1.0,1.2,1.5,1.22,2.0,5.0,3.5,3.0,9]
plt.hist(Data, bins = 5)
# Out:
# (array([5., 2., 1., 0., 1.]),
#  array([1. , 2.6, 4.2, 5.8, 7.4, 9. ]),
#  <a list of 5 Patch objects>)
